# %%
import numpy as np

np.random.seed(42)

def feed_forward(x, W1, b1, W2, b2):
    hidden = x @ W1 + b1
    hidden = np.maximum(0, hidden)
    output = hidden @ W2 + b2
    return output

batch_size = 2
seq_len = 4
d_model = 8
d_ff = 32

x = np.random.randn(batch_size, seq_len, d_model)

W1 = np.random.randn(d_model, d_ff)
b1 = np.random.randn(d_ff)

W2 = np.random.randn(d_ff, d_model)
b2 = np.random.randn(d_model)

output = feed_forward(x, W1, b1, W2, b2)

print(x.shape)
print(output.shape)
print(output)
# Out:
# (2, 4, 8)
# (2, 4, 8)
# [[[ 10.12834836   6.19136172  12.47674208   0.42246681  -2.4831391
#     -2.8660806   -6.12583005 -18.02751932]
#   [-11.82357635  -0.27735222   7.19690556   3.27152565  -2.29191161
#    -12.8801826  -22.65521319 -10.77206013]
#   [  5.59979994  11.29662027  12.38803337   2.77460011   2.12745214
#    -21.19113353 -13.43597023  -0.92586153]
#   [-13.45562258   0.86910377  11.67665555  -0.8285545   11.40314602
#     10.13214718  -4.31474761  -5.32203447]]
#
#  [[-10.30623257   0.34029525  12.08445912   3.78367114  -7.82859613
#    -14.86684483 -31.80441491 -14.24389594]
#   [ -0.28090247   3.3484954    8.5997676   -5.11029244   3.45432535
#      1.85259265 -18.23320893 -15.25697091]
#   [  5.43372295   2.09470473  13.14774711   2.55376415  -5.09865566
#      1.34014751  -6.87011017 -16.3637917 ]
#   [-13.8038597    0.40163472  10.5125395    3.33527789  -1.90139384
#     11.7603232   -0.86608394  -7.58005976]]]
